# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

data = pd.read_csv("IGTV.csv")
print(data.head())
# Out:
#              account                       business_category_name  \
# 0        yazilim.exe                       Creators & Celebrities
# 1  yazilimci.genclik        Non-Profits & Religious Organizations
# 2    yazilim.academy  Personal Goods & General Merchandise Stores
# 3       yahya.kassid                                          NaN
# 4           xnetking                                          NaN
#
#    Total Views  Unique viewers  Comments  Total Likes is_business_account  \
# 0          880            57.0       7.0          354                 yes
# 1        24036          1013.0       4.0          103                 yes
# 2         2827            82.0      13.0         6695                 yes
# 3         1345            79.0      12.0          169                  no
# 4          208            18.0       6.0           73                  no
#
#   is_professional_account
# 0                     yes
# 1                     yes
# 2                     yes
# ...

# %%
data = pd.read_csv("IGTV.csv", encoding="latin-1")

# %%
data = pd.read_csv("IGTV.csv", encoding="utf-8")

# %%
figure = px.bar(data, x=data["account"], 
                y = data["Total Views"], 
                color = data["Total Views"],
            title="Total Views per IGTV")
figure.show()

# %%
figure = px.bar(data, x=data["account"], 
                y = data["Total Likes"], 
                color = data["Total Likes"],
            title="Total Likes per IGTV")
figure.show()

# %%
figure = px.bar(data, x=data["account"],
                y=data["Unique viewers"],
                color= data["Unique viewers"],
            title="Total Unique Viewers per IGTV")
figure.show()

# %%
print(data.isnull().sum())
# Out:
# account                       0
# business_category_name     1179
# Total Views                   0
# Unique viewers               12
# Comments                     12
# Total Likes                   0
# is_business_account           3
# is_professional_account       3
# dtype: int64
